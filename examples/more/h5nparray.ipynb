# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

from labmate.syncdata import SyncData  # pyright: ignore[reportMissingImports]


def measure(size):
    return np.random.random(size)  # noqa: NPY002
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
d = SyncData("tmp_data/test.h5", overwrite=True, save_on_edit=False)

# %%
size1, size2 = 2, 3
d["a1"] = d.h5nparray(np.zeros((size1, size2), dtype=np.float64))

# %%
d.a1[1, 2] = 1.4

# %%
d.save()
# Out:
# SyncData (rw):
#  {
#     "a1": "shape: (2, 3) (type: H5NpArray)"
# }

# %%
read = SyncData("tmp_data/test.h5", read_only=False, overwrite=False)
read.a1
# Out:
# array([[0. , 0. , 0. ],
#        [0. , 0. , 1.4]])
