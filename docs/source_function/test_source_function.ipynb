# %%
# %load_ext autoreload
# %autoreload 2

import docs.source_function.save_source_function as save_source_function
import docs.source_function.some_module as some_module

# from save_source_function import get_source_functions

import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
save_source_function.get_source_functions(some_module.test2)
# Out:
# {'docs.source_function.some_module.test2': {'code': 'def test2(x):\n    b = 2\n    t = SomeClass()\n    return x + test() + external_variable + b + some_module2.test3() + test4() + t.test6()\n',
#   'type': 'function',
#   'file': '/Users/4cd87a/Documents/Projects/PhD/codes/labmate/docs/source_function/some_module.py',
#   'external_vars': ['docs.source_function.some_module.test',
#    'docs.source_function.some_module.external_variable',
#    'docs.source_function.some_module.SomeClass',
#    'some_module2.test4',
#    'some_module2']},
#  'docs.source_function.some_module.test': {'code': 'def test():\n    return 2\n',
#   'type': 'function',
#   'file': '/Users/4cd87a/Documents/Projects/PhD/codes/labmate/docs/source_function/some_module.py',
#   'external_vars': []},
#  'docs.source_function.some_module.external_variable': {'type': 'variable',
#   'value': '1'},
#  'docs.source_function.some_module.SomeClass': {'code': 'class SomeClass:\n    def __init__(self):\n        self.a = 1\n\n    def test6(self):\n        return 2\n',
#   'type': 'class',
#   'file': '/Users/4cd87a/Documents/Projects/PhD/codes/labmate/docs/source_function/some_module.py',
#   'external_vars': []},
#  'some_module2.test4': {'code': 'def test4():\n    return 2\n',
#   'type': 'function',
#   'file': '/Users/4cd87a/Documents/Projects/PhD/codes/labmate/docs/source_function/some_module2.py',
#   'external_vars': []}}

# %%
import save_source_function


def test():
    return 2


def some_function(x):
    import numpy as np

    return x + test()


# This will return both "some_function" and "test" with their source code
source_functions = save_source_function.get_source_functions(some_function)
source_functions
# Out:
# {'some_function': {'code': 'def some_function(x):\n    import numpy as np\n    return x + test()',
#   'external_vars': ['test', 'numpy'],
#   'file': 'unknown'},
#  'test': {'code': 'def test():\n    return 2',
#   'external_vars': [],
#   'file': 'unknown'}}

# %%
import save_source_function


def test():
    return 2


def some_function(x):
    import numpy as np

    return x + test()


# This will return both "some_function" and "test" with their source code
source_functions = save_source_function.get_source_functions(some_function)
source_functions
# Out:
# {'some_function': {'code': 'def some_function(x):\n    import numpy as np\n    return x + test()',
#   'external_vars': ['test', 'numpy'],
#   'file': 'unknown'},
#  'test': {'code': 'def test():\n    return 2',
#   'external_vars': [],
#   'file': 'unknown'}}
