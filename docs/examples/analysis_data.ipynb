# %%
# %load_ext autoreload
# %autoreload 2

import smart_import

import numpy as np
from quanalys.acquisition_utils import AnalysisData
import quanalys.acquisition_utils.h5py_utils as h5py_utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
d = AnalysisData()

# %%
d._save_on_edit
# Out:
# False

# %%
d['t'] = {'a':[1,2], 'b':[2,3,4]}

# %%
(1,2)[0]=2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/4cd87a/Documents/Projects/PhD/codes/acquisition_utils/docs/examples/analysis_data.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/4cd87a/Documents/Projects/PhD/codes/acquisition_utils/docs/examples/analysis_data.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> (1,2)[0]=2
#
# TypeError: 'tuple' object does not support item assignment
