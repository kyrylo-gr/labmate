# %%
# %load_ext autoreload
# %autoreload 2

import smart_import

import numpy as np
from quanalys.syncdata import SyncData
# Out:
# Kernel is started

# %%
sd = SyncData('tmp_data/test.h5', overwrite=True, save_on_edit=True)

# %%
sd.a1 = [2,3,4]
